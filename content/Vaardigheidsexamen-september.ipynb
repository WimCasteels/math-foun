# %% [markdown]
# # Herexamen Mathematical Foundations — September 2026 — Praktijk
#
# ---
#
# Dit praktijkherexamen bevat **4 vragen**, verdeeld over de vier hoofdstukken van de cursus. Per hoofdstuk is er één lange en één korte vraag.
#
# Beantwoord elke vraag met code en druk je resultaten af met `print()`. Maak grafieken waar gevraagd. Schrijf je redenering, waar gevraagd, als commentaar in de code.
#
# Sla als je klaar bent de notebook met je antwoorden op en dien deze in op toets.ap.be.
#
# Veel succes!

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

np.set_printoptions(precision=4, suppress=True)
np.random.seed(42)

print("Libraries geladen!")

# %% [markdown]
# ---
# ## Deel 1 — Lineaire Algebra

# %% [markdown]
# ### Vraag 1 (kort) — Vectorprojectie en cosine similarity
#
# Gegeven de vectoren `p = [3, -1, 2, 4]` en `q = [-2, 5, 1, 0]`.
#
# **a)** Bereken de **orthogonale projectie** van `p` op `q`:
#
# $$\text{proj}_q(p) = \frac{p \cdot q}{q \cdot q} \cdot q$$
#
# **b)** Toon aan dat het **residu** `r = p - proj_q(p)` loodrecht staat op `q` (dot product is 0).
#
# **c)** Bereken de **cosine similarity** tussen `p` en `q`, en de bijhorende **hoek in graden**.

# %%
p = np.array([3, -1, 2,  4])
q = np.array([-2, 5,  1,  0])

# Jouw code:

# %% [markdown]
# ---
# ## Deel 2 — Analyse (Calculus)

# %% [markdown]
# ### Vraag 2 — Gradient descent op een 2D loss landscape
#
# Beschouw de loss functie:
#
# $$L(w_1, w_2) = (w_1 - 2)^2 + 3(w_2 + 1)^2 + w_1 \cdot w_2$$
#
# **a)** Implementeer `loss(w1, w2)` en bereken de **analytische partiële afgeleiden**
# $\frac{\partial L}{\partial w_1}$ en $\frac{\partial L}{\partial w_2}$.
# Schrijf de formules als commentaar en implementeer ze als functies.
#
# **b)** Verifieer de partiële afgeleiden **numeriek** (met `h = 1e-5`) op het punt `(w1, w2) = (1.0, 0.5)`.
#
# **c)** Voer **50 iteraties gradient descent** uit vanaf `(w1, w2) = (4.0, 3.0)` met leersnelheid (learning rate) `η = 0.05`.
# Sla alle `(w1, w2, L)`-waarden op.
#
# **d)** Maak een **contourplot** van `L(w1, w2)` en teken het pad van gradient descent als een rode lijn met punten. Markeer het startpunt en eindpunt.
#
# **e)** Plot ook de **loss-curve** over de 50 iteraties in een tweede grafiek. Convergeert de loss? Naar welke waarde?

# %%
def loss(w1, w2):
    return (w1 - 2)**2 + 3*(w2 + 1)**2 + w1*w2

# dL/dw1 = ...   (analytisch, als commentaar)
# dL/dw2 = ...   (analytisch, als commentaar)

# Jouw code:

# %% [markdown]
# ### Vraag 3 — Kettingregel en activatiefuncties
#
# Definieer de samengestelde functie:
#
# $$h(x) = \tanh\!\left(3x^2 - 2x + 1\right)$$
#
# **a)** Bereken de **analytische afgeleide** `h'(x)` via de kettingregel.
# Schrijf de tussenstappen als commentaar:
# - Binnenste functie `g(x)` en `g'(x)`
# - Buitenste functie `f(u)` en `f'(u)` (onthoud: $\tanh'(u) = 1 - \tanh^2(u)$)
#
# **b)** Implementeer `h(x)` en `h_prime(x)` in Python en evalueer beide op `x = -1`, `x = 0` en `x = 1.5`.
#
# **c)** Verifieer `h'(x)` **numeriek** op dezelfde punten (gebruik `h = 1e-5`).

# %%
# h(x) = tanh(3x² - 2x + 1)
# g(x) = 3x² - 2x + 1  →  g'(x) = ...
# f(u) = tanh(u)        →  f'(u) = ...
# h'(x) = f'(g(x)) * g'(x) = ...

def h(x):
    pass  # vervang dit

def h_prime(x):
    pass  # vervang dit

# Jouw code:

# %% [markdown]
# ---
# ## Deel 3 — Statistiek

# %% [markdown]
# ### Vraag 4 — Verwachtingswaarde, variantie en softmax
#
# **a)** Een dataset bevat 5 klassen met respectievelijk 420, 310, 180, 60 en 30 voorbeelden.
# Bereken:
# - De **kans** op elke klasse (als een willekeurig voorbeeld wordt gekozen)
# - De **verwachtingswaarde** van het klassenummer (weeg de klasse-indices 0–4 met hun kans)
# - De **variantie** van het klassenummer
#
# **b)** Een neuraal netwerk geeft de volgende logits voor één voorbeeld:
# `logits = [1.2, -0.5, 2.8, 0.3, -1.1]`.
#
# Pas **softmax** toe en druk de kansverdeling af. Toon dat de kansen sommeren tot 1.
#
# **c)** Bereken de **entropie** van de softmax-verdeling:
# $$H = -\sum_i p_i \log(p_i)$$
#
# Vergelijk dit met de entropie van een **uniforme** verdeling over 5 klassen. Welke is groter en waarom?

# %%
class_counts = np.array([420, 310, 180, 60, 30])
logits = np.array([1.2, -0.5, 2.8, 0.3, -1.1])

# Jouw code:
